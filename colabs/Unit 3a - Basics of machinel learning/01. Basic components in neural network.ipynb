# %% [markdown]
# Exploring neural network structure without coding:
#
# https://cloud.google.com/blog/products/ai-machine-learning/understanding-neural-networks-with-tensorflow-playground
#
# Problem type
# Data:
# Easy: exclusive / gaussian dataset (a straight line can separate data with different labels)
# Medium: circle (quadratic functions can separate data with different labels)
# Hard: spiral (a higher degree polynomial to separate data with different labels)
#
# ## Model setting parameters:
# Training data / Test data ratio:
# This determines the proportion of the total dataset that is used for training versus testing.
#
# Noise:
# This refers to the degree of randomness or unpredictability in the data. High noise can make it harder for a neural network to learn the underlying pattern.
# We might add little bit of noise to mimic if there are some imperfections in our datasets
#
# Batch size:
# the number of training examples used in one iteration of model training. Larger batch sizes can lead to faster training, but may also risk overfitting
#
# Feature:
# In machine learning, a feature is an individual measurable property or characteristic of a data instance. Different features can provide different perspectives on the data, and choosing the right features is critical for good performance.
#
# Hidden layers:
# hidden layers are layers of nodes between the input and output layers. Each layer can learn different features of the data. Increasing the number of hidden layers can help the network learn more complex patterns, but it also increases the risk of overfitting.
#
# Learning rate:
# This is a hyperparameter that determines how much the model changes in response to the estimated error each time the model weights are updated. If the learning rate is too high, the model might overshoot the optimal solution.
#
# Activation:
# The activation function determines the output of a neural network's node. It's used to introduce non-linearity into the network, allowing it to learn more complex patterns.
#
# Regularization:
# This is a technique used to prevent overfitting by adding a penalty to the loss function based on the complexity of the model. The two most common types of regularization are L1 and L2.
#
# Regularization rate:
# This is a hyperparameter that determines the degree of regularization. A larger regularization rate increases the penalty for complexity, making the model simpler but potentially reducing its ability to learn complex patterns.
#
# ## Result display settings:
# Discretize output:
# This option will present the output of the network as discrete values, which is especially useful for classification tasks.
#
# Show test data:
# Test data are unseen data for the model. This option will overlay the test data on the graph of the decision boundaries. This allows you to visually assess how well your model is generalizing to unseen data.

# %% [markdown]
# ## More complex learning object
#
# It is not often the case that our datasets are well separated. Simple neural network cannot complete the task.

# %% [markdown]
# Failed attempt:
#
# 1. Underfitting
#
# When the neural network cannot generate a nice boundary to separate data with different labels. It is rather underfitting or overfitting.
# In the snapshot below we can see that the test loss of the model plateau on around 0.45.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Failed attempt 2: Overfitting
#
# Now we try to set a model with a lot of neurons and layers. We can see that test loss does not converge and bouncing between 0.15 to 0.3.
# It is because the model has too much parameters which leads to overfitting.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Strategy of creating a proper neural network
#
# 1) Regularization (L1 promotes sparsity (which is good for feature selection), L2 promotes smooth solutions when sparsity is not required)
# 2) Using dropout to later layers

# %% [markdown]
# Possible answer 1:
#
# ![image.png](attachment:image.png)

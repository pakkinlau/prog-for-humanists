# %% [markdown]
# ## Download dataset from remote server

# %%
import datasets

dataset_id = "alturing/gutenberg-texts"

# Load the dataset by name
dataset = datasets.load_dataset(dataset_id)

# Download the dataset files
print(dataset)

""" 
DatasetDict({
    train: Dataset({
        features: ['title', 'author', 'text', 'language'],
        num_rows: 2951
    })
})

"""
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'author', 'text', 'language'],
#         num_rows: 2951
#     })
# })
# " \nDatasetDict({\n    train: Dataset({\n        features: ['title', 'author', 'text', 'language'],\n        num_rows: 2951\n    })\n})\n\n"

# %%
# Save the dataset to a local folder
local_folder_path = r"C:\Users\kinla\Documents\All_github_repo\datasets\gutenberg"
dataset.save_to_disk(local_folder_path)
# Out:
# Saving the dataset (0/2 shards):   0%|          | 0/2951 [00:00<?, ? examples/s]

# %%
# View the set of files in that folder

import os

local_folder_path = r"C:\Users\kinla\Documents\All_github_repo\datasets\gutenberg"

def list_files_and_folders(directory_path, indent=""):
    print(f"{indent}+ {os.path.basename(directory_path)}")
    indent += "    "
    
    # Separate different directories for clarity
    sline = "-" * 30
    print(f"{indent}{sline}")
    
    for filename in os.listdir(directory_path):
        filepath = os.path.join(directory_path, filename)
        if os.path.isdir(filepath):
            list_files_and_folders(filepath, indent)
        else:
            print(f"{indent}- {filename}")

    print(f"{indent}{sline}")

# Call the function to list files in the specified directory
list_files_and_folders(local_folder_path)
# Out:
# + gutenberg
#     ------------------------------
#     - dataset_dict.json
#     + train
#         ------------------------------
#         - data-00000-of-00002.arrow
#         - data-00001-of-00002.arrow
#         - dataset_info.json
#         - state.json
#         ------------------------------
#     ------------------------------

# %% [markdown]
# ## Open PyArrow files

# %%
from datasets import load_dataset

# Path to the directory containing the dataset
dataset_path = local_folder_path

# Load dataset from arrow shards
dataset = load_dataset("arrow", data_files=[f"{dataset_path}/train/data-00000-of-00002.arrow", 
                                            f"{dataset_path}/train/data-00001-of-00002.arrow"])

# Access dataset elements
print(dataset)  # Access the first data point in the dataset
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'author', 'text', 'language'],
#         num_rows: 2951
#     })
# })

# %% [markdown]
# ## Explore PyArrow dataset

# %%
print(dataset) # it returns DatasetDict, because the directory contains multiple folders
print(dataset['train']) # it returns Dataset, because we also indicate the name of the folder
print(dataset['train']['title'])
print(dataset['train']['text'][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'author', 'text', 'language'],
#         num_rows: 2951
#     })
# })
# Dataset({
#     features: ['title', 'author', 'text', 'language'],
#     num_rows: 2951
# })
# ["Memoirs of a griffin         Or, A cadet's first year in India    ", 'Maggie Lee!         Bad spelling, Diamonds, The answered prayer    ', 'The unwelcome child         Or, The crime of an undesigned and undesired maternity    ', 'The Nightingale    ', 'Re-creations    ', 'Le supplice de PhÃ¨dre    ', 'Gypsy folk-tales    ', "Father Duffy's story    ", 'Home education         Home Education Series (Vol. 1 of 6)    ', 'The outcast    ', 'Satuja         Lukemisia Suomen rahvaalle Pietarista II    ', 'Anna Hollmannin hÃ¤viÃ¶         Kertomus    ', 'The rag pickers         and other stories    ', 'Little maid Marigold    ', 'Her country    ', 'Seetrien alla         Romaani    ', 'Satuja ja tarinoita VII    ', 'Natalika    ', 'Mere mortals         Medico-historical essays    ', 'Mary Rose         A play in three acts    ', 'Dig me no grave    ', 'The hyena    ', 'Charmes    ', 'A Wilful Ward    ', 'Constantinople    ', 'Holidays at Brighton         or, sea-side amusements    ', 'Kun silmÃ¤t aukenevat    ', 'La segunda casaca    ', "Sous d'humbles toits    ", 'Paraboles et diversions    ', 'The dream snake    ', 'My dear Cornelia    ', 'The red planet    ', 'Lewis and Irene    ', 'Poster advertising         Being a talk on the subject of posting as an advertising medium,         with helpful hints and sensible suggestions to poster         advertisers, and with thirty-two pages', 'ElÃ¤mÃ¤n pelko    ', 'The Gamblers    ', 'John Williams         Or the sailor boy    ', 'Fanciful tales    ', "The spokesman's secretary         Being the letters of Mame to Mom    ", "Jasper's old shed         And how the light shone in    ", 'Friendless Felicia         Or a little city sparrow    ', 'Il costruttore Solness    ', 'Kultaa    ', 'En croupe de Bellone    ', 'Venezuela    ', 'Hollywoodin tyttÃ¶    ', 'The British Soldier         His Courage and Humour    ', 'KesÃ¤matkoilla kanootissa    ', 'IdÃ¤n Ã¤Ã¤reltÃ¤         Kuvia ja luonnoksia Japanista    ', 'Metsien mies         KolminÃ¤ytÃ¶ksinen nÃ¤ytelmÃ¤    ', 'Between the twilights         Being studies of Indian women by one of themselves    ', 'Tusayan katcinas    ', 'Debits and Credits    ', 'Mary of Lorraine         An historical romance    ', 'The public and its problems    ', 'The human species    ', 'The complete works of John Gower, volume 1         The French works    ', "Amore ha cent'occhi    ", "The D'Arblay mystery    ", 'Lectures pour une ombre    ', "Rogo d'amore    ", "L'Uomo di Fuoco    ", 'The book of The Cheese         Being traits and stories of "Ye Olde Cheshire Cheese"    Editors: William Hussey Graham           R. R. D. Adams           Frank Banfield    Compiler: T. W. Reid    Rele', 'Richard Wagner    ', 'A vol de vÃ©lo         De Paris Ã\xa0 Vienne    ', 'Neidon ryÃ¶stÃ¶         KolminÃ¤ytÃ¶ksinen huvinÃ¤ytelmÃ¤    ', 'Mildred         A novel    ', 'En las orillas del Sar    ', 'Vagabonds of the sea         The campaign of a French cruiser    ', 'The romance of excavation         A record of the amazing discoveries in Egypt, Assyria, Troy,         Crete, etc.    ', 'The Little Gentleman    ', 'Good For Evil         or Rose Cottage    ', 'The Radiant City         An Allegory    ', 'Parturi ja prinssi    ', 'The Man-killers    ', 'The East I know    ', 'Tragedy in Dedham         The story of the Sacco-Venzetti case    ', 'The Danube    ', 'The unhallowed harvest    ', 'The Tracy diamonds    ', 'The wrong letter    ', 'Heortology         A history of the Christian festivals from their origin to the         present day    ', 'The sentinel stars    ', 'PilaesitelmiÃ¤    ', 'Kuninkaan miekkamies         Historiallinen seikkailuromaani    ', 'Joking apart    ', 'The treasury of languages         A rudimentary dictionary of universal philology    ', "Clerambault         Histoire d'une concience libre pendant la guerre    ", 'Trois femmes    ', 'The model prayer         A series of expositions on "The Lord\'s Prayer"    ', 'In memoriam    ', 'Kuningas kivihiili    ', 'Viisi pi ...
# ï»¿The Project Gutenberg eBook of Memoirs of a griffin, by Francis John   Bellew    This eBook is for the use of anyone anywhere in the United States and  most other parts of the world at no cost and with almost no restrictions  whatsoever. You may copy it, give it away or re-use it under the terms  of the Project Gutenberg License included with this eBook or online at  www.gutenberg.org. If you are not located in the United States, you  will have to check the laws of the country where you are located before  using this eBook.    Title: Memoirs of a griffin         Or, A cadet's first year in India    Author: Francis John  Bellew    Release Date: July 3, 2023 [eBook #71100]    Language: English    Credits: Richard Tonsing and the Online Distributed Proofreading Team at           https://www.pgdp.net (This file was produced from images           generously made available by The Internet Archive)    *** START OF THE PROJECT GUTENBERG EBOOK MEMOIRS OF A GRIFFIN ***      [Illustration: Griffin Marching to Join.]                                    MEMOIRS OF A GRIFFIN                                    OR,                       A CADETâS FIRST YEAR IN INDIA.                                         BY                                CAPTAIN BELLEW.                     _ILLUSTRATED FROM DESIGNS BY THE AUTHOR._                                   A New Edition.                                       LONDON              W. H. ALLEN & CO., LTD., 13 WATERLOO PLACE. S.W.                      PUBLISHERS TO THE INDIA OFFICE.                                   1891.                                             TO                  MAJOR-GEN. SIR ROBERT CUNLIFFE, BART., C.B.,                                       OF     ACTON PARK, DENBIGHSHIRE, LATE COMMISSARY-GENERAL OF THE BENGAL ARMY,     IN WHOSE DEPARTMENT THE AUTHOR HAD FOR SOME YEARS THE HONOUR TO SERVE,                                THIS LITTLE WORK          IS RESPECTFULLY DEDICATED, AS A MARK OF HIS SINCERE ESTEEM.                                          PREFACE.      Good wine, says the proverb, needs no bush; on the same principle, some  will think that a book, if readable, may dispense with a preface. As a  general rule this may be true, but there are occasions, and I take leave  to deem this one of them, when, from the peculiar nature of the subject,  a few preliminary observations, by creating a clear and possibly a  pleasant understanding between the author and the gentle reader, may not  be unacceptable or out of place. In the following little narrative, in  which I have blended fact and fictionâthough always endeavouring to keep  the _vraisemblable_ in viewâmy object has been to depict some of those  scenes, characters, and adventures, which some five-and-twenty or thirty  years ago a âjolly cadetââalias a Griffinâwas likely to encounter,  during the first year of his military career; men, manners, and things  in general have, since that period, undergone considerable changes;  still, in its main features, the sketch I have drawn, admitting its  original correctness, will doubtless apply as well to Griffins in the  present mature age of the century, as when it was in its teens. The  Griffin, or Greenhorn, indeed, though subject, like everything else, to  the external changes incident to time and fashion, is, perhaps,  fundamentally and essentially, one of the ânever ending, still  beginningâ states, or phases of humanity, destined to exist till the  âcrash of doom.â    The characters which I have introduced in my narrative (for the most  part as transiently as the fleeting shadows of a magic lantern across a  spectrum) are all intended to represent respectively classes having more  or less of an Oriental stamp, some still existing unchangedâothers on  the waneâand a few, I would fain hope, who, like the Trunnions and  Westerns (_parva componere magnis_) of the last age have wholly  disappeared before the steadily increasing light of knowledge and  civil ...

# %% [markdown]
# ## Explore dataset with pandas

# %%
import pandas as pd

df = pd.DataFrame.from_dict(dataset['train'])

def objprint(object):
    """
    This function takes an object as input, prints the name of the object
    (in this case, the type or name of the function) and then prints the
    output of that object when called. 

    Parameters:
    object (callable): An object (function, class, etc.) that can be called
                       to produce an output.
    """
    func_name = str(object)  # Get the name of the object as a string
    func_output = object   # Call the object to get its output
    
    print(f" The object name is: {func_name}")         # Print the name of the object
    print(f" The object output is: {func_output}")     # Print the output of the object

objprint(df.head)
objprint(df.describe())
objprint(df.info())
# Out:
#  The object name is: <bound method NDFrame.head of                                                   title  \
# 0     Memoirs of a griffin         Or, A cadet's fir...
# 1     Maggie Lee!         Bad spelling, Diamonds, Th...
# 2     The unwelcome child         Or, The crime of a...
# 3                                   The Nightingale
# 4                                      Re-creations
# ...                                                 ...
# 2946                               Exile From Venus
# 2947                          Into the Frozen South
# 2948                                     A tragikum
# 2949  Die KringhÃ¤usler         Drama in drei Akten
# 2950
#
#                         author  \
# 0        Francis John  Bellew
# 1              Mary J. Holmes
# 2             Henry C. Wright
# 3     Hans Christian Andersen
# 4       Grace Livingston Hill
# ...                        ...
# 2946         E. Hoffman Price
# 2947               James Marr
# 2948            JenÅ RÃ¡kosi
# 2949  Alma Maximiliane Karlin
# 2950
#
#                                                    text    language
# 0     ï»¿The Project Gutenberg eBook of Memoirs of a...    English
# 1     ï»¿The Project Gutenberg eBook of Maggie Lee!,...    English
# 2     ï»¿The Project Gutenberg eBook of The unwelcom...    English
# 3     ï»¿The Project Gutenberg eBook of The Nighting...    English
# 4     ï»¿The Project Gutenberg eBook of Re-creations...    English
# ...                                                 ...         ...
# 2946  ï»¿The Project Gutenberg eBook of Exile From V...    English
# 2947  ï»¿The Project Gutenberg eBook of Into the Fro...    English
# 2948  ï»¿The Project Gutenberg eBook of A tragikum, ...  Hungarian
# 2949  ï»¿The Project Gutenberg eBook of Die KringhÃ¤...     German
# 2950  <!DOCTYPE html> <html class="client-nojs" lang...
#
# [2951 rows x 4 columns]>
#  The object output is: <bound method NDFrame.head of                                                   title  \
# 0     Memoirs of a griffin         Or, A cadet's fir...
# 1     Maggie Lee!         Bad spelling, Diamonds, Th...
# 2     The unwelcome child         Or, The crime of a...
# 3                                   The Nightingale
# 4                                      Re-creations
# ...                                                 ...
# 2946                               Exile From Venus
# 2947                          Into the Frozen South
# 2948                                     A tragikum
# 2949  Die KringhÃ¤usler         Drama in drei Akten
# 2950
#
#                         author  \
# 0        Francis John  Bellew
# 1              Mary J. Holmes
# 2             Henry C. Wright
# 3     Hans Christian Andersen
# 4       Grace Livingston Hill
# ...                        ...
# 2946         E. Hoffman Price
# 2947               James Marr
# 2948            JenÅ RÃ¡kosi
# 2949  Alma Maximiliane Karlin
# 2950
#
#                                                    text    language
# 0     ï»¿The Project Gutenberg eBook of Memoirs of a...    English
# 1     ï»¿The Project Gutenberg eBook of Maggie Lee!,...    English
# 2     ï»¿The Project Gutenberg eBook of The unwelcom...    English
# 3     ï»¿The Project Gutenberg eBook of The Nighting...    English
# 4     ï»¿The Project Gutenberg eBook of Re-creations...    English
# ...                                                 ...         ...
# 2946  ï»¿The Project Gutenberg eBook of Exile From V...    English
# 2947  ï»¿The Project Gutenberg eBook of Into the Fro...    English
# 2948  ï»¿The Project Gutenberg eBook of A tragikum, ...  Hungarian
# 2949  ï»¿The Project Gutenberg eBook of Die KringhÃ¤...     German
# 2950  <!DOCTYPE html> <html class="client-nojs" lang...
#
# [2951 rows x 4 columns]>
#  The object name is:        title      author                                               text  \
# count   2951        2951                                               2951
# unique  2931        1859                                               2938
# top           Anonymous   <!DOCTYPE html> <html class="client-nojs" lang...
# freq      15          96                                                 13
#
#         language
# count       2951
# unique        26
# top     English
# freq        2224
#  The object output is:        title      author                                               text  \
# count   2951        2951                                               2951
# unique  2931        1859                                               2938
# top           Anonymous   <!DOCTYPE html> <html class="client-nojs" lang...
# freq      15          96                                                 13
#
#         language
# count       2951
# unique        26
# top     English
# freq        2224
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2951 entries, 0 to 2950
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     2951 non-null   object
#  1   author    2951 non-null   object
#  2   text      2951 non-null   object
#  3   language  2951 non-null   object
# dtypes: object(4)
# memory usage: 92.3+ KB
#  The object name is: None
#  The object output is: None

# %%
df_flattened = pd.json_normalize(dataset['train'], sep='_')
print(df_flattened.head())
# Out:
#                                                title  \
# 0  Memoirs of a griffin         Or, A cadet's fir...
# 1  Maggie Lee!         Bad spelling, Diamonds, Th...
# 2  The unwelcome child         Or, The crime of a...
# 3                                The Nightingale
# 4                                   Re-creations
#
#                      author  \
# 0     Francis John  Bellew
# 1           Mary J. Holmes
# 2          Henry C. Wright
# 3  Hans Christian Andersen
# 4    Grace Livingston Hill
#
#                                                 text  language
# 0  ï»¿The Project Gutenberg eBook of Memoirs of a...  English
# 1  ï»¿The Project Gutenberg eBook of Maggie Lee!,...  English
# 2  ï»¿The Project Gutenberg eBook of The unwelcom...  English
# 3  ï»¿The Project Gutenberg eBook of The Nighting...  English
# 4  ï»¿The Project Gutenberg eBook of Re-creations...  English

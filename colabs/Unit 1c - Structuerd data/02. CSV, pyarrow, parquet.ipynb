# %% [markdown]
# ## CSV, pyarrow and parquet
#
# ![image.png](attachment:image.png)
#
# In our course, we focus on several structured file formats apart from databases, including CSV, PyArrow, and Parquet.
#
# CSV (Comma-Separated Values) is a widely used flat file format that resembles Excel spreadsheets.
#
# Parquet is a columnar storage file format designed for big data processing. It supports schema evolution, allowing for changes in the data structure over time.
#
# PyArrow, on the other hand, is a cross-language development platform for in-memory data that provides a standardized language-independent interface. It also supports the Parquet file format, allowing for efficient and flexible data storage and processing.
#
# In summary, CSV is a basic flat file format, Parquet is a columnar big data format with schema evolution capabilities, and PyArrow is a versatile platform that supports various data formats, including Parquet.
#
# We won't delve into the intricacies of these three file formats, but let's explore the process of loading data from these types in Python.

# %%
# !pip install datasets
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %% [markdown]
# ## Loading CSV

# %%
from datasets import load_dataset

"""Load online CSV"""
# Replace 'dataset_name' with the name of the dataset you want to load
dataset_name = 'gbharti/finance-alpaca-csv'
# Specify the split you want to load (e.g., 'train', 'test')
split = 'train'
# Load the dataset
dataset = load_dataset(dataset_name, split=split)
# Print information about the loaded split of the dataset
print(dataset)

"""Load local CSV"""
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File c:\Users\kinla\AppData\Local\Programs\Python\Python310\lib\site-packages\datasets\builder.py:1940, in ArrowBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1933     writer = writer_class(
#    1934         features=writer._features,
#    1935         path=fpath.replace("SSSSS", f"{shard_id:05d}").replace("JJJJJ", f"{job_id:05d}"),
#    (...)
#    1938         embed_local_files=embed_local_files,
#    1939     )
# -> 1940 writer.write_table(table)
#    1941 num_examples_progress_update += len(table)
#
# ...

# %% [markdown]
# ## Loading pyarrow

# %% [markdown]
# ## Load Parquet

# %% [markdown]
# # Unit 0: Overview of the course
#
# ## Lecture notes
# - [Unit 0: Overview of the course](Unit0.ipynb)
#
# ## Labs
# - [Unit 0R1: pair-programming tools, github overview](Unit0R1.ipynb)
# - [Unit 0R2: python basics and programming principles](Unit0R2.ipynb)
# - [Unit 0R3: Introduction to git bash, git repositories and version control](Unit0R3.ipynb)
#
# ## Readings
# - ABC
# - DEF
#
# ---
#
# # Unit 1 - Data collection and preprocessing
#
# ## Lecture notes
# - [Unit 1a: Data preparation - Art images](Unit1a.ipynb)
# - [Unit 1b: Data preparation - Literatures, text corpus](Unit1b.ipynb)
#
# ## Labs:
#
# ## Readings:
#
# ---
#
# # Unit 2 - Data and database management
#
# - [Unit 2a: MongoDB document structure, collections, indexes](Unit2a.ipynb)
# - [Unit 2b: MongoDB database design, CRUD operations]
#
#
# ---
# # Unit 3 - Introduction to machine learning and its application
#
# - [Unit 3a: Machine learning basics]
# - [Unit 3b: Model training and application]
#
# ---
# # Unit 4 - Benchmarking, visualization and project deployment
#
# - [Unit 4a: Evaluations of MongoDB and PyTorch models]
# - [Unit 4b: Visualization, deployment and publication]
